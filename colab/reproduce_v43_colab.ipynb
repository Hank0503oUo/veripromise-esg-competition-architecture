# %% [markdown]
# # v43 Final Submission Reproduction
#
# This notebook reproduces `submission_v43_tlonly_v39d.csv` from deterministic artifacts. It does not call any LLM API and does not train models.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Set the competition root and package directory. Adjust these paths if your Drive layout is different.

# %%
ESG_ROOT = '/content/drive/MyDrive/ESG競賽'
PKG = ESG_ROOT + '/esg_competition/HARNESS/v43_repro_package'
print('ESG_ROOT =', ESG_ROOT)
print('PKG =', PKG)

# %%
# %pip install -q -r "{PKG}/requirements.txt"

# %% [markdown]
# Optional but recommended: rebuild the v39d timeline source from deterministic feature artifacts.

# %%
# !python "{PKG}/scripts/build_v39d_timeline.py" --root "{ESG_ROOT}"

# %% [markdown]
# Reproduce the final v43 submission and verify the expected SHA256.

# %%
# !python "{PKG}/scripts/reproduce_v43.py" --root "{ESG_ROOT}"

# %% [markdown]
# The output report is written to `esg_competition/outputs/v43_repro_report.json`.
